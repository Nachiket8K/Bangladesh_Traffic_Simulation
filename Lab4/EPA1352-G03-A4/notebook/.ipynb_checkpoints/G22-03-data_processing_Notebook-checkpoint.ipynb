# %% [markdown]
# This notebook creates a csv file in the necessary format.

# %%
import pandas as pd
from scipy.spatial import distance

# load raw datafiles into DataFrames
roads = pd.read_csv("../data/raw/_roads3.csv")
bridges = pd.read_excel('../data/raw/BMMS_overview.xlsx', engine='openpyxl')

# %%
#--- Identifying side roads of N1 and N2

# Only keep N1 and N2
df = roads.loc[(roads["road"] == "N1") | (roads["road"] == "N2")]

# List of all roads
Roads = roads['road'].unique().tolist()

# List of all crossroads and side roads (in ugly format)
names = df['name'].tolist()

# Find roads that appear in the crossroads / sideroads 
side_roads = [road for road in Roads if any(road in name for name in names)]
print("there are", len(Roads), " roads, and ", len(side_roads), "side roads to N1 and N2")
# Out:
# there are 847  roads, and  103 side roads to N1 and N2

# %%
#--- Filtering for side roads over 25km long

# Take all side roads
sideroads_df = roads[roads['road'].isin(side_roads)]

# Filter for those over 25km long (aka LRPE had chainage >25)
sideroads_ends = sideroads_df.loc[(sideroads_df["lrp"] == "LRPE") & (sideroads_df["chainage"] > 25)]
sideroads_tokeep = sideroads_ends['road'].tolist()

# Apply filter
sideroads_df = sideroads_df.loc[(sideroads_df['road'].isin(sideroads_tokeep))]

# %%
#--- Adding a length to each road segment

# Create the length column
sideroads_df["length"] = sideroads_df["chainage"]*1000 
sideroads_df = sideroads_df.reset_index(drop=True)

# Change the chainage to a length
for i in range((len(sideroads_df)-1),0,-1):
    if sideroads_df["road"][i] == sideroads_df["road"][i-1]:
        sideroads_df.loc[i,"length"] = sideroads_df.loc[i,"length"]-sideroads_df.loc[i-1,"length"]

# %%
#--- Moving on to bridges!

# Filter for relevant columns and relevant roads
bridges_relevant = bridges[["road", "LRPName", "condition", "length", "chainage", "lat", "lon", 'name', 'km','constructionYear']]
bridges_relevant = bridges_relevant.loc[bridges['road'].isin(side_roads)]
bridges_relevant = bridges_relevant.reset_index(drop = True)

bridgestemp = bridges_relevant # useful in a second

# Only keep right side of each bridge
for i in range(1,len(bridges_relevant)):
    if len(str(bridges_relevant["name"][i])) > 4:
        if bridges_relevant["name"][i][-2:] == 'L)' or bridges_relevant["name"][i][-4:] == 'eft)' or bridges_relevant["name"][i][-3:] == 'L )' or bridges_relevant["name"][i][-4:] == 'EFT)':
            bridgestemp = bridgestemp.drop(i,axis = 0)

# Delete depulicates by removing older information
#  assumption: no 2 lrps in the same road have the exact same km
bridges_relevant = bridgestemp \
    .sort_values(by=['road','km','constructionYear'], ascending=False) \
    .drop_duplicates(subset=['road', 'km'], keep='first')

# %%
#--- Bringing relevant roads and bridges together 

# Prepare merge
bridges_relevant = bridges_relevant.rename(columns={"LRPName": "lrp"})

# Merge
merged = pd.merge(sideroads_df, bridges_relevant, how="outer", on=["road", "lrp"])
merged = merged.reset_index(drop = True)

# Add model_type
merged["model_type"] = merged["lrp"].apply(lambda x: "sourcesink" if x == "LRPS" else ("sourcesink" if x == "LRPE" else "link"))
merged.loc[merged["condition"].notnull(), "model_type"] = "bridge"

# Fill in missing data
merged["chainage_x"] = merged["chainage_x"].fillna(value=merged["chainage_y"])
merged["lat_x"] = merged["lat_x"].fillna(value=merged["lat_y"])
merged["lon_x"] = merged["lon_x"].fillna(value=merged["lon_y"])
merged["name_y"] = merged["name_y"].fillna(value=merged["name_x"])
merged["length_x"] = merged["length_x"].fillna(value=merged["length_y"])

# Keep and rename useful columns only
merged = merged.sort_values(by=['road','chainage_x'],ascending = True)
col_tokeep = ["road", "model_type", "lrp", "name_y", "lat_x", "lon_x", "length_x", "condition","type"]
merged = merged[col_tokeep]
merged = merged.rename(columns={"name_y": "name","lat_x" : "lat", "lon_x" : "lon", "length_x" : "length"})
merged = merged.reset_index(drop = True)

# Add ids
merged["id"] =  range(1000000, len(merged) +1000000 )

# %%
cross_sideroads = merged.loc[(merged['type'].str.contains("CrossRoad"))| (merged['type'].str.contains("SideRoad"))]
cross_sideroads = cross_sideroads.reset_index()
cross_sideroads.iloc[60:70,:]
# Out:
#     index road model_type      lrp                          name        lat  \
# 60    936   N1       link  LRP337a     Road to Badarkhali (R172)  21.759639
# 61    950   N1       link  LRP341b       Road to Alikadam(Z1005)  21.721555
# 62    965   N1     bridge  LRP348a              FULCHARI CULVERT  21.668833
# 63    985   N1       link  LRP354c  Z1131, Kutakhali-Maheshkhali  21.615056
# 64   1056   N1     bridge  LRP376a                    MUKTAR KUL  21.449472
# 65   1070   N1       link  LRP378c       Ramu old Section (N109)  21.428499
# 66   1112   N1     bridge  LRP386c           DALA-2 SLAB CULVERT  21.425860
# 67   1213   N1       link  LRP403c           Road to Ramu(Z1009)  21.317666
# 68   1217   N1     bridge  LRP404a            UKLIA-SHAHABMARKAT  21.310167
# 69   1255   N1     bridge  LRP413a                     BALUKHALI  21.244750
#
#           lon  length condition            type       id
# 60  92.076499   575.0       NaN  SideRoad,Right  1000936
# 61  92.083083   163.0       NaN   SideRoad,Left  1000950
# 62  92.075944    96.0         A   SideRoad,Left  1000965
# 63  92.066777    59.0       NaN  SideRoad,Right  1000985
# 64  92.099527    57.0         A   SideRoad,Left  1001056
# 65  92.095194    79.0       NaN   SideRoad,Left  1001070
# 66  92.023166    65.0         A  SideRoad,Right  1001112
# 67  92.093027    82.0       NaN   SideRoad,Left  1001213
# 68  92.097500   220.0         C   SideRoad,Left  1001217
# 69  92.138944   300.0         B   SideRoad,Left  1001255

# %%
#--- Defining the intersections

# subset the dataframe to only the rows that indicate an intersection
cross_sideroads = merged.loc[(merged['type'].str.contains("CrossRoad"))| (merged['type'].str.contains("SideRoad"))]
cross_sideroads = cross_sideroads.reset_index()

roads_done = []
# iterate over all road rows that are crossroads or sideroads
for i,crossrow in cross_sideroads.iterrows():
    # check if any of those roads indicate in their name that they intersect with a road that crosses the N1 and/or N2
    for j in sideroads_tokeep:
        if j in str(crossrow["name"]) and j != crossrow["road"]:
            # if you are not trying one intersection that you already did the other way around
            if i not in roads_done:
                found = False
                # iterate over all points in that intersecting road to see if any of those indicate to be an intersection with the road at hand
                # since a road can cross another road on multiple occasions, we only look as far as 1 lat and 1 lon
                for k,roadrow in merged[merged['road'] == j].iterrows():
                    if crossrow["name"] in roadrow["name"] and (roadrow["lat"] - crossrow["lat"] < 1) and (roadrow["lon"] - crossrow["lon"] < 1) and crossrow["road"] != roadrow["road"]:
                        # if this finds the intersection point, make its id, lat and lon the same and make the model_type "intersection"
                        merged.iloc[k,9] = cross_sideroads.iloc[i,10]
                        merged.iloc[k,4] = cross_sideroads.iloc[i,5]
                        merged.iloc[k,5] = cross_sideroads.iloc[i,6]
                        merged.iloc[k,1] = "intersection"
                        merged.iloc[cross_sideroads.iloc[i,0],1] = "intersection"
                        #print("made indersection here1:",merged.iloc[k,:],merged.iloc[cross_sideroads.iloc[i,0],1])
                        # save the fact that you have handled this intersection
                        found = True
                        roads_done.append(i)
                # if you didnt find the intersecting road through the name, assign the closest road point as the intersection
                # assumption: projection is so small that it will not distort the distance to much so we can use euclidean distance to determine the closest point
                if found == False:
                    closestrow = merged.iloc[[0]]
                    closestindex = 0
                    closestdistance = 1000
                    p1 = (crossrow["lat"],crossrow["lon"])
                    # calculate for each road point the distance to the intersection, save it if it is closer than what you found before
                    for k,roadrow in merged[merged['road'] == j].iterrows():
                        p2 = (roadrow["lat"],roadrow["lon"])
                        if distance.euclidean(p1, p2) < closestdistance:
                            closestrow = roadrow
                            closestindex = k
                            closestdistance = distance.euclidean(p1, p2)
                    # of the closest point, make the id, lat and lon the same and make the model_type "intersection"
                    merged.iloc[closestindex,9] = cross_sideroads.iloc[i,10]
                    merged.iloc[closestindex,4] = cross_sideroads.iloc[i,5]
                    merged.iloc[closestindex,5] = cross_sideroads.iloc[i,6]
                    merged.iloc[closestindex,1] = "intersection"
                    merged.iloc[cross_sideroads.iloc[i,0],1] = "intersection"
                    #print("made indersection here2:",merged.iloc[k,:],"other roadpoint:",merged.iloc[cross_sideroads.iloc[i,0],:])
                    # save the fact that you have handled this intersection
                    roads_done.append(i)
# Out:
# made indersection here2: road                            N2
# model_type              sourcesink
# lrp                           LRPE
# name          Road End at Jaflong.
# lat                        25.1571
# lon                        92.0176
# length                         256
# condition                      NaN
# type                        Others
# id                         1002995
# Name: 2995, dtype: object other roadpoint: road                           N1
# model_type           intersection
# lrp                       LRP009a
# name          Road to Sylhet (N2)
# lat                       23.7061
# lon                       90.5215
# length                        260
# condition                     NaN
# type                SideRoad,Left
# id                        1000019
# Name: 19, dtype: object
# made indersection here2: road                                Z1042
# model_type                     sourcesink
# lrp                                  LRPE
# name          Fathepur Connect with R203.
# lat                               23.7812
# lon                               90.8287
# length                                658
# condition                             NaN
# type                               Others
# id                                1006297
# Name: 6297, dtype: object other roadpoint: road                                   N1
# model_type                   intersection
# lrp                               LRP056c
# name          Z1042, road to Bancharampur
# lat                               23.5127
# lon                               90.8714
# length                                102
# condition                             NaN
# type                        SideRoad,Left
# id                                1000158
# Name: 158, dtype: object
# made indersection here2: road                             N102
# model_type                 sourcesink
# lrp                              LRPE
# name          Meet with N 2 at Sanail
# lat                           24.0506
# lon                           91.1147
# length                            549
# condition                         NaN
# type                           Others
# id                            1001782
# Name: 1782, dtype: object other roadpoint: road                                  N1
# model_type                  intersection
# lrp                              LRP084a
# name          Road to Brahmanbaria(N102)
# lat                               23.479
# lon                              91.1182
# length                                17
# condition                            NaN
# type                       SideRoad,Left
# id                               1000210
# Name: 210, dtype: object
# made indersection here2: road                                                      Z1034
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          End of Road at Sonagazi Intersection  point of...
# lat                                                      22.836
# lon                                                     91.4545
# length                                                      191
# condition                                                   NaN
# type                                                     Others
# id                                                      1006132
# Name: 6132, dtype: object other roadpoint: road                                 N1
# model_type                 intersection
# lrp                             LRP152a
# name          Road to Feni Town (Z1034)
# lat                             22.9878
# lon                               91.41
# length                              448
# condition                           NaN
# type                      SideRoad,Left
# id                              1000383
# Name: 383, dtype: object
# made indersection here2: road                                                      Z1034
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          End of Road at Sonagazi Intersection  point of...
# lat                                                      22.836
# lon                                                     91.4545
# length                                                      191
# condition                                                   NaN
# type                                                     Others
# id                                                      1006132
# Name: 6132, dtype: object other roadpoint: road                                N1
# model_type                intersection
# lrp                            LRP152b
# name          Road to Sonagazi (Z1034)
# lat                            22.9859
# lon                            91.4121
# length                             296
# condition                          NaN
# type                    SideRoad,Right
# id                             1000384
# Name: 384, dtype: object
# made indersection here2: road                                                       R151
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          The road end Intersecting R160 at Hadchokia ,F...
# lat                                                     22.7082
# lon                                                     91.7841
# length                                                       80
# condition                                                   NaN
# type                                                     Others
# id                                                      1003688
# Name: 3688, dtype: object other roadpoint: road                               N1
# model_type               intersection
# lrp                           LRP170b
# name          Road to Karerhat (R151)
# lat                            22.894
# lon                           91.5347
# length                            637
# condition                         NaN
# type                    SideRoad,Left
# id                            1000419
# Name: 419, dtype: object
# made indersection here2: road                                                      Z1065
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          The Road end at Jastipura and Further Assessme...
# lat                                                     22.4042
# lon                                                     91.9944
# length                                                      180
# condition                                                   NaN
# type                                                     Others
# id                                                      1006766
# Name: 6766, dtype: object other roadpoint: road                                  N1
# model_type                  intersection
# lrp                              LRP251b
# name          Road to Balakkhati (Z1065)
# lat                              22.3106
# lon                              91.8571
# length                                30
# condition                            NaN
# type                       SideRoad,Left
# id                               1000663
# Name: 663, dtype: object
# made indersection here2: road                                                       R170
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          Road End With R172 at Eidmoni Badarkhali -Chok...
# lat                                                     21.7522
# lon                                                     92.0078
# length                                                       67
# condition                                                   NaN
# type                                                     Others
# id                                                      1003950
# Name: 3950, dtype: object other roadpoint: road                              N1
# model_type              intersection
# lrp                          LRP268c
# name          Road to Anowara (R170)
# lat                          22.2918
# lon                          91.9823
# length                            21
# condition                        NaN
# type                  SideRoad,Right
# id                           1000712
# Name: 712, dtype: object
# made indersection here2: road                                Z1005
# model_type                     sourcesink
# lrp                                  LRPE
# name          The road ends at Lama Bazar
# lat                               21.7774
# lon                               92.1948
# length                               3160
# condition                             NaN
# type                               Others
# id                                1005645
# Name: 5645, dtype: object other roadpoint: road                               N1
# model_type               intersection
# lrp                           LRP341b
# name          Road to Alikadam(Z1005)
# lat                           21.7216
# lon                           92.0831
# length                            163
# condition                         NaN
# type                    SideRoad,Left
# id                            1000950
# Name: 950, dtype: object
# made indersection here2: road                                                  R203
# model_type                                    intersection
# lrp                                                   LRPE
# name          Road Connect with N-102 at Radhika ,B.Baria.
# lat                                                23.9033
# lon                                                91.1266
# length                                                 245
# condition                                              NaN
# type                                                Others
# id                                                 1001738
# Name: 4239, dtype: object other roadpoint: road                               N102
# model_type                 intersection
# lrp                             LRP064a
# name          R203 on left to Nabinagar
# lat                             23.9033
# lon                             91.1266
# length                              285
# condition                           NaN
# type                      SideRoad,Left
# id                              1001738
# Name: 1738, dtype: object
# made indersection here2: road                                                         N1
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          End of Road at Shapla Chattar ,Teknaf Meet wit...
# lat                                                     20.8629
# lon                                                     92.2981
# length                                                      130
# condition                                                   NaN
# type                                                     Others
# id                                                      1001554
# Name: 1554, dtype: object other roadpoint: road                    N102
# model_type      intersection
# lrp                  LRP070c
# name           N103 on Right
# lat                  23.9571
# lon                  91.1156
# length                   130
# condition                NaN
# type          SideRoad,Right
# id                   1001756
# Name: 1756, dtype: object
# made indersection here2: road                                                         N1
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          End of Road at Shapla Chattar ,Teknaf Meet wit...
# lat                                                     20.8629
# lon                                                     92.2981
# length                                                      130
# condition                                                   NaN
# type                                                     Others
# id                                                      1001554
# Name: 1554, dtype: object other roadpoint: road                              N2
# model_type              intersection
# lrp                          LRP012a
# name          Intersection with N105
# lat                          23.7853
# lon                          90.5686
# length                           268
# condition                        NaN
# type                       CrossRoad
# id                           1002051
# Name: 2051, dtype: object
# made indersection here2: road                                                  R203
# model_type                                    intersection
# lrp                                                   LRPE
# name          Road Connect with N-102 at Radhika ,B.Baria.
# lat                                                23.9033
# lon                                                91.1266
# length                                                 245
# condition                                              NaN
# type                                                Others
# id                                                 1001738
# Name: 4239, dtype: object other roadpoint: road                          N2
# model_type          intersection
# lrp                      LRP012d
# name          R203 to Ramchandri
# lat                      23.7857
# lon                      90.5706
# length                       460
# condition                    NaN
# type              SideRoad,Right
# id                       1002054
# Name: 2054, dtype: object
# made indersection here2: road                                                       R301
# model_type                                         intersection
# lrp                                                        LRPE
# name          End of road at Pachdona intersecting N2, Dhaka...
# lat                                                     23.8934
# lon                                                     90.6644
# length                                                      917
# condition                                                   NaN
# type                                                     Others
# id                                                      1002097
# Name: 5082, dtype: object other roadpoint: road                                                         N2
# model_type                                         intersection
# lrp                                                     LRP030b
# name          R301 to Ghorashal, Z2047 to Ghorashal / Sylhet...
# lat                                                     23.8934
# lon                                                     90.6644
# length                                                      909
# condition                                                   NaN
# type                                     SideRoad,Left / KmPost
# id                                                      1002097
# Name: 2097, dtype: object
# made indersection here2: road                                                 R211
# model_type                                     sourcesink
# lrp                                                  LRPE
# name          The road ends Intersecting R360 at Kotiadi.
# lat                                               24.2523
# lon                                               90.7967
# length                                                956
# condition                                             NaN
# type                                               Others
# id                                                1004356
# Name: 4356, dtype: object other roadpoint: road                                        N2
# model_type                        intersection
# lrp                                    LRP043b
# name          R310 to Gazipur ,R211 to Shibpur
# lat                                    23.9802
# lon                                    90.7334
# length                                     648
# condition                                  NaN
# type                             SideRoad,Left
# id                                     1002141
# Name: 2141, dtype: object
# made indersection here2: road                                                       R360
# model_type                                         intersection
# lrp                                                        LRPE
# name          End of Road of Durjoy more Bhairab interseting...
# lat                                                     24.0554
# lon                                                     90.9829
# length                                                       32
# condition                                                   NaN
# type                                                     Others
# id                                                      1002233
# Name: 5471, dtype: object other roadpoint: road                                 N2
# model_type                 intersection
# lrp                             LRP071a
# name          Road to Kishoreganj(R360)
# lat                             24.0554
# lon                             90.9829
# length                              478
# condition                           NaN
# type                      SideRoad,Left
# id                              1002233
# Name: 2233, dtype: object
# made indersection here2: road                                                       N204
# model_type                                         intersection
# lrp                                                        LRPE
# name          Road End intersecting N2 at Shaistagonj Round ...
# lat                                                     24.2677
# lon                                                     91.4769
# length                                                      134
# condition                                                   NaN
# type                                                     Others
# id                                                      1002478
# Name: 3105, dtype: object other roadpoint: road                                              N2
# model_type                              intersection
# lrp                                          LRP142b
# name          R240 to Habiganj / N204 to Chunarughat
# lat                                          24.2677
# lon                                          91.4769
# length                                           251
# condition                                        NaN
# type                  SideRoad,Left / SideRoad,Right
# id                                           1002478
# Name: 2478, dtype: object
# made indersection here2: road                                                       N207
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          Road end with N2 at Mukti joddha Chattor Sherpur.
# lat                                                     24.6263
# lon                                                     91.6775
# length                                                      350
# condition                                                   NaN
# type                                                     Others
# id                                                      1003289
# Name: 3289, dtype: object other roadpoint: road                               N2
# model_type               intersection
# lrp                           LRP146b
# name          Road to Srimongal(N207)
# lat                           24.2947
# lon                           91.5101
# length                            639
# condition                         NaN
# type                   SideRoad,Right
# id                            1002494
# Name: 2494, dtype: object
# made indersection here2: road                                                       R240
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          Road end with N2 ( Dhaka- Syhlet Road at Auska...
# lat                                                     24.5938
# lon                                                     91.6105
# length                                                     1250
# condition                                                   NaN
# type                                                     Others
# id                                                      1004647
# Name: 4647, dtype: object other roadpoint: road                               N2
# model_type               intersection
# lrp                           LRP182c
# name          Road to Nabiganj (R240)
# lat                           24.5911
# lon                           91.6014
# length                            189
# condition                         NaN
# type                    SideRoad,Left
# id                            1002679
# Name: 2679, dtype: object
# made indersection here2: road                                  Z2013
# model_type                       sourcesink
# lrp                                    LRPE
# name          Road End With Borobaga River.
# lat                                 24.6572
# lon                                 91.8282
# length                                  575
# condition                               NaN
# type                                 Others
# id                                  1007461
# Name: 7461, dtype: object other roadpoint: road                                N2
# model_type                intersection
# lrp                            LRP225b
# name          Road to Balaganj (Z2013)
# lat                            24.8673
# lon                            91.8568
# length                             658
# condition                          NaN
# type                    SideRoad,Right
# id                             1002811
# Name: 2811, dtype: object
# made indersection here2: road                                                       N208
# model_type                                         intersection
# lrp                                                        LRPE
# name          Road end at Humayun Rashid Chattar, Intersecti...
# lat                                                     24.8777
# lon                                                     91.8753
# length                                                      900
# condition                                                   NaN
# type                                                     Others
# id                                                      1002823
# Name: 3484, dtype: object other roadpoint: road                                      N2
# model_type                      intersection
# lrp                                  LRP228c
# name             N209 / N208 to Moulovibazar
# lat                                  24.8777
# lon                                  91.8753
# length                                   169
# condition                                NaN
# type          SideRoad,Left / SideRoad,Right
# id                                   1002823
# Name: 2823, dtype: object
# made indersection here2: road                            N2
# model_type              sourcesink
# lrp                           LRPE
# name          Road End at Jaflong.
# lat                        25.1571
# lon                        92.0176
# length                         256
# condition                      NaN
# type                        Others
# id                         1002995
# Name: 2995, dtype: object other roadpoint: road                              N208
# model_type                intersection
# lrp                            LRP054a
# name          N210, Sylhet Bypass road
# lat                             24.848
# lon                            91.8966
# length                             677
# condition                          NaN
# type                    SideRoad,Right
# id                             1003476
# Name: 3476, dtype: object
# made indersection here2: road                                Z1042
# model_type                   intersection
# lrp                                  LRPE
# name          Fathepur Connect with R203.
# lat                               23.7812
# lon                               90.8287
# length                                658
# condition                             NaN
# type                               Others
# id                                1004081
# Name: 6297, dtype: object other roadpoint: road                                   R203
# model_type                     intersection
# lrp                                 LRP032a
# name          Fathepur more, int.with Z1042
# lat                                 23.7812
# lon                                 90.8287
# length                                   52
# condition                               NaN
# type                         SideRoad,Right
# id                                  1004081
# Name: 4081, dtype: object
# made indersection here2: road                            N2
# model_type              sourcesink
# lrp                           LRPE
# name          Road End at Jaflong.
# lat                        25.1571
# lon                        92.0176
# length                         256
# condition                      NaN
# type                        Others
# id                         1002995
# Name: 2995, dtype: object other roadpoint: road                    R250
# model_type      intersection
# lrp                  LRP002a
# name          N2 (Over pass)
# lat                  24.8789
# lon                  91.8772
# length                    74
# condition                NaN
# type               CrossRoad
# id                   1004776
# Name: 4776, dtype: object
# made indersection here2: road                            N2
# model_type              sourcesink
# lrp                           LRPE
# name          Road End at Jaflong.
# lat                        25.1571
# lon                        92.0176
# length                         256
# condition                      NaN
# type                        Others
# id                         1002995
# Name: 2995, dtype: object other roadpoint: road                                  R250
# model_type                    intersection
# lrp                                LRP007a
# name          N210,Sylhet town Bypass road
# lat                                24.8582
# lon                                91.9277
# length                                 820
# condition                              NaN
# type                             CrossRoad
# id                                 1004786
# Name: 4786, dtype: object
# made indersection here2: road                                                         N1
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          End of Road at Shapla Chattar ,Teknaf Meet wit...
# lat                                                     20.8629
# lon                                                     92.2981
# length                                                      130
# condition                                                   NaN
# type                                                     Others
# id                                                      1001554
# Name: 1554, dtype: object other roadpoint: road                               R301
# model_type                 intersection
# lrp                             LRP006a
# name          N105, Madanpur- Joydevpur
# lat                               23.93
# lon                             90.4526
# length                              898
# condition                           NaN
# type                          CrossRoad
# id                              1005015
# Name: 5015, dtype: object
# made indersection here2: road                                                 R211
# model_type                                   intersection
# lrp                                                  LRPE
# name          The road ends Intersecting R360 at Kotiadi.
# lat                                               24.2523
# lon                                               90.7967
# length                                                956
# condition                                             NaN
# type                                               Others
# id                                                1005410
# Name: 4356, dtype: object other roadpoint: road                                  R360
# model_type                    intersection
# lrp                                LRP086a
# name          R211, Itakhola- Katiadi road
# lat                                24.2523
# lon                                90.7967
# length                                 282
# condition                              NaN
# type                        SideRoad,Right
# id                                 1005410
# Name: 5410, dtype: object
# made indersection here2: road                                                         N1
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          End of Road at Shapla Chattar ,Teknaf Meet wit...
# lat                                                     20.8629
# lon                                                     92.2981
# length                                                      130
# condition                                                   NaN
# type                                                     Others
# id                                                      1001554
# Name: 1554, dtype: object other roadpoint: road                           Z1031
# model_type              intersection
# lrp                          LRP007a
# name          Side Road, Right, N104
# lat                          23.0101
# lon                           91.399
# length                           495
# condition                        NaN
# type                  SideRoad,Right
# id                           1005956
# Name: 5956, dtype: object
# made indersection here2: road                                                         N1
# model_type                                           sourcesink
# lrp                                                        LRPE
# name          End of Road at Shapla Chattar ,Teknaf Meet wit...
# lat                                                     20.8629
# lon                                                     92.2981
# length                                                      130
# condition                                                   NaN
# type                                                     Others
# id                                                      1001554
# Name: 1554, dtype: object other roadpoint: road                                 Z1034
# model_type                    intersection
# lrp                                LRP002a
# name          Start of Natianal Highway N1
# lat                                22.9878
# lon                                  91.41
# length                                 652
# condition                              NaN
# type                             CrossRoad
# id                                 1000383
# Name: 6062, dtype: object
# made indersection here1: road                                N1
# model_type                intersection
# lrp                            LRP260c
# name          Road to Kalurghat (N107)
# lat                            22.3746
# lon                            91.9063
# length                             121
# condition                          NaN
# type                     SideRoad,Left
# id                             1006716
# Name: 694, dtype: object intersection

# %%
# show it worked
merged.iloc[690:700,:]
# Out:
#     road    model_type      lrp                      name        lat  \
# 690   N1          link  LRP259b  Road to Kaliganj (Z1070)  22.309694
# 691   N1          link   LRP260               Box culvert  22.311417
# 692   N1        bridge  LRP260a         PALYA BUS STATION  22.312472
# 693   N1          link  LRP260b               Box culvert  22.315639
# 694   N1  intersection  LRP260c  Road to Kalurghat (N107)  22.374638
# 695   N1        bridge  LRP252c             UTTOR SONAPUR  22.315747
# 696   N1          link   LRP261           Km post missing  22.315556
# 697   N1        bridge  LRP261a              SRIMI BRIDGE  22.313778
# 698   N1          link   LRP262           Km post missing  22.313750
# 699   N1          link   LRP263           Km post missing  22.313639
#
#            lon  length condition           type       id
# 690  91.915750   424.0       NaN      CrossRoad  1000690
# 691  91.917638   273.0       NaN         KmPost  1000691
# 692  91.918833   168.0         A        Culvert  1000692
# 693  91.922499   521.0       NaN        Culvert  1000693
# 694  91.906278   121.0       NaN  SideRoad,Left  1006716
# 695  91.924352     3.0         A            NaN  1000695
# 696  91.925388   190.0       NaN         KmPost  1000696
# 697  91.932222   750.0         C        Culvert  1000697
# 698  91.934527   250.0       NaN         KmPost  1000698
# 699  91.943889  1000.0       NaN         KmPost  1000699

# %%
merged.loc[merged["id"] == 1006716]
# Out:
#        road    model_type      lrp                      name        lat  \
# 694      N1  intersection  LRP260c  Road to Kalurghat (N107)  22.374638
# 6716  Z1065  intersection  LRP013e                      N107  22.374638
#
#             lon  length condition           type       id
# 694   91.906278   121.0       NaN  SideRoad,Left  1006716
# 6716  91.906278    20.0       NaN      CrossRoad  1006716

# %%
# as the above code does not find all intersections, here is a more crude way to find them anyhow based on the closeness of the points in different roads
# warning: takes a very long time to run
#for i, row in merged.iterrows():
#    if row['model_type'] != 'bridge':
#        for j in range(i,len(merged)):
#            if merged['model_type'][j] != 'bridge':
#                if row['id'] != merged['id'][j] and row['road'] != merged['road'][j] and distance.euclidean((row['lat'],row['lon']), (merged['lat'][j],merged['lon'][j])) < 0.0001:
#                    merged.iloc[j,9] = merged.iloc[i,9]
#                    merged.iloc[j,4] = merged.iloc[i,4]
#                    merged.iloc[j,5] = merged.iloc[i,5]
#                    merged.iloc[j,1] = "intersection"
#                    print('new intersection made at id',row['id'],'between', row['road'], 'and', merged['road'][j])
# Out:
# new intersection made at id 1000210 between N1 and N102
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-263bf39f6f82> in <module>
#       5         for j in range(i,len(merged)):
#       6             if merged['model_type'][j] != 'bridge':
# ----> 7                 if row['id'] != merged['id'][j] and row['road'] != merged['road'][j] and distance.euclidean((row['lat'],row['lon']), (merged['lat'][j],merged['lon'][j])) < 0.0001:
#       8                     merged.iloc[j,9] = merged.iloc[i,9]
#       9                     merged.iloc[j,4] = merged.iloc[i,4]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4377         # use this, e.g. DatetimeIndex
#    4378         # Things like `Series._get_value` (via .at) pass the EA directly here.
# -> 4379         s = extract_array(series, extract_numpy=True)
#    4380         if isinstance(s, ExtensionArray):
#    4381             if is_scalar(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in extract_array(obj, extract_numpy)
#     378     """
#     379     if isinstance(obj, (ABCIndexClass, ABCSeries)):
# --> 380         obj = obj.array
#     381
#     382     if extract_numpy and isinstance(obj, ABCPandasArray):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in array(self)
#     516     @property
#     517     def array(self) -> ExtensionArray:
# --> 518         return self._data._block.array_values()
#     519
#     520     def _internal_get_values(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in array_values(self)
#     221         The array that Series.array returns. Always an ExtensionArray.
#     222         """
# --> 223         return PandasArray(self.values)
#     224
#     225     def get_values(self, dtype=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\numpy_.py in __init__(self, values, copy)
#     151
#     152         self._ndarray = values
# --> 153         self._dtype = PandasDtype(values.dtype)
#     154
#     155     @classmethod
#
# KeyboardInterrupt:

# %%
# as the above code does not find all intersections, here is a more crude way to find them anyhow based on the closeness of the points in different roads
# warning: takes a very long time to run
#for i, row in merged.iterrows():
#    if row['model_type'] != 'bridge':
#        for j, newrow in merged.iterrows():
#            if i < j and newrow['model_type'] != 'bridge':
#                if row['id'] != newrow['id'] and row['road'] != newrow['road'] and distance.euclidean((row['lat'],row['lon']), (newrow['lat'],newrow['lon'])) < 0.0001:
#                    merged.iloc[j,9] = merged.iloc[i,9]
#                    merged.iloc[j,4] = merged.iloc[i,4]
#                    merged.iloc[j,5] = merged.iloc[i,5]
#                    merged.iloc[j,1] = "intersection"
#                    print('new intersection made at id',row['id'],'between', row['road'], 'and', newrow['road'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-00c6e858c8d0> in <module>
#       5         for j, newrow in merged.iterrows():
#       6             if i < j and newrow['model_type'] != 'bridge':
# ----> 7                 if row['id'] != newrow['id'] and row['road'] != newrow['road'] and distance.euclidean((row['lat'],row['lon']), (newrow['lat'],newrow['lon'])) < 0.0001:
#       8                     merged.iloc[j,9] = merged.iloc[i,9]
#       9                     merged.iloc[j,4] = merged.iloc[i,4]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# KeyboardInterrupt:

# %%
#--- Adapting to the newest csv guidelines

# Adapting names
#move bridge names to a new column 
merged["bridge_name"] = merged["name"].loc[merged['model_type'] == "bridge"]
#delete names for everything and replace that of SourceSinks according to convention
i = 1 # useful in a second
for index, row in merged.iterrows():
    if not row['model_type'] == "sourcesink":
        merged["name"][index] = ""
        
    elif row['model_type'] == "sourcesink":
        merged["name"][index] = "SoSi" + str(i)
        merged["condition"][index] = ""
        i += 1

# Put columns in right order
merged = merged[["road", "id", "model_type", "condition", "name", "lat", "lon", "length", "bridge_name"]]
merged.head()
# Out:
# <ipython-input-100-eb02f822f98d>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged["name"][index] = "SoSi" + str(i)
# <ipython-input-100-eb02f822f98d>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged["condition"][index] = ""
# <ipython-input-100-eb02f822f98d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged["name"][index] = ""
#   road       id  model_type condition   name        lat        lon  length  \
# 0   N1  1000000  sourcesink            SoSi1  23.706028  90.443333     0.0
# 1   N1  1000001        link       NaN         23.702917  90.450417   814.0
# 2   N1  1000002        link       NaN         23.702778  90.450472     8.0
# 3   N1  1000003        link       NaN         23.702139  90.451972   178.0
# 4   N1  1000004      bridge         A         23.698739  90.458861    11.3
#
#   bridge_name
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4           .

# %%
# Save to csv 
merged.to_csv("../data/processed/N1_N2_plus_sideroads.csv", index=None)

# %%
roads.head(20)
